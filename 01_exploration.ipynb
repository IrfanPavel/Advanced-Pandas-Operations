# %% [markdown]
# <a href="https://colab.research.google.com/github/IrfanPavel/Advanced-Pandas-Operations/blob/main/01_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data exploration

# %% [markdown]
# We use the dataset found at https://github.com/mkcor/data-wrangling/blob/master/data/tidy_who.csv
# (see the notebook at the root of that repo for the generation of this dataset).

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/tidy_who.csv')

# %% [markdown]
# ## Loading data

# %% [markdown]
# ... just works. `read_csv()` comes with many convenient arguments, such as `skiprows`, `nrows`, `na_values`, etc. Note that, alternatively, we could have run `df = pd.read_csv('https://raw.githubusercontent.com/mkcor/data-wrangling/master/data/tidy_who.csv')`.

# %%
df.head()
# Out:
#        country g_whoregion    year  cases type sex  age_range
# 0  Afghanistan         EMR  1980.0    NaN   sp   m       14.0
# 1  Afghanistan         EMR  1981.0    NaN   sp   m       14.0
# 2  Afghanistan         EMR  1982.0    NaN   sp   m       14.0
# 3  Afghanistan         EMR  1983.0    NaN   sp   m       14.0
# 4  Afghanistan         EMR  1984.0    NaN   sp   m       14.0

# %%
df.shape
# Out:
# (359501, 7)

# %%
df.sample(10)
# Out:
#                                    country g_whoregion    year  cases type  \
# 189324                            Pakistan         EMR  1999.0    NaN   sn
# 14167                            Swaziland         AFR  2001.0  180.0   sp
# 226452                               Libya         EMR  1986.0    NaN   ep
# 15124   Venezuela (Bolivarian Republic of)         AMR  2008.0  364.0   sp
# 67113                Saint Kitts and Nevis         AMR  1996.0    NaN   sp
# 75709                           Tajikistan         EUR  2007.0  243.0   sp
# 2171                    Dominican Republic         AMR  2015.0    NaN   sp
# 217378                              France         EUR  1990.0    NaN   ep
# 343008                         Philippines         WPR  1987.0    NaN  rel
# 269667                   Brunei Darussalam         WPR  2007.0    0.0   ep
#
#        sex  age_range
# 189324   f     3544.0
# 14167    m     1524.0
# 226452   m     1524.0
# 15124    m     1524.0
# 67113    f     1524.0
# 75709    f     2534.0
# 2171     m       14.0
# 217378   m       14.0
# 343008   m     2534.0
# 269667   f       14.0

# %%
df.describe()
# Out:
#                 year          cases      age_range
# count  359500.000000   76213.000000  359500.000000
# mean     1997.570946     612.188432    2524.520512
# std        10.407826    4130.724688    1951.063158
# min      1980.000000       0.000000      14.000000
# 25%      1989.000000       3.000000      65.000000
# 50%      1998.000000      26.000000    2534.000000
# 75%      2007.000000     186.000000    4554.000000
# max      2015.000000  250051.000000    5564.000000

# %%
df['g_whoregion'].unique()
# Out:
# array(['EMR', 'EUR', 'AFR', 'WPR', 'AMR', 'SEA', nan], dtype=object)

# %%
df['country'].nunique()
# Out:
# 219

# %% [markdown]
# ## Selecting data

# %% [markdown]
# We are already familiar with column selection. The `[ ]` syntax is the most basic way of indexing.

# %%
df['country'].head(3)
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# Name: country, dtype: object

# %% [markdown]
# Columns can also be accessed as attributes (as long as they have a valid Python name).

# %%
df.country[1000:1003]
# Out:
# 1000    Brazil
# 1001    Brazil
# 1002    Brazil
# Name: country, dtype: object

# %% [markdown]
# We can select elements of a DataFrame either by label (with the `.loc` attribute) or by position (with the `.iloc` attribute). Row and column indices take the usual order (first and second place, respectively).

# %%
df.loc[0, 'country']
# Out:
# 'Afghanistan'

# %%
df.loc[df.shape[0] - 1, 'country']
# Out:
# 'Swaziland'

# %%
df.iloc[0, 0]
# Out:
# 'Afghanistan'

# %%
df.iloc[df.shape[0] - 1, 0]
# Out:
# 'Swaziland'

# %% [markdown]
# Slicing works too.

# %%
df.loc[:5, 'country']
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# 5    Afghanistan
# Name: country, dtype: object

# %% [markdown]
# Label indexing is more natural than positional indexing (think of a function call, where keyword arguments are easier to work with than positional arguments).

# %%
df.loc[:5, 'country':'type']
# Out:
#        country g_whoregion    year  cases type
# 0  Afghanistan         EMR  1980.0    NaN   sp
# 1  Afghanistan         EMR  1981.0    NaN   sp
# 2  Afghanistan         EMR  1982.0    NaN   sp
# 3  Afghanistan         EMR  1983.0    NaN   sp
# 4  Afghanistan         EMR  1984.0    NaN   sp
# 5  Afghanistan         EMR  1985.0    NaN   sp

# %%
df.iloc[:5, :5]
# Out:
#        country g_whoregion    year  cases type
# 0  Afghanistan         EMR  1980.0    NaN   sp
# 1  Afghanistan         EMR  1981.0    NaN   sp
# 2  Afghanistan         EMR  1982.0    NaN   sp
# 3  Afghanistan         EMR  1983.0    NaN   sp
# 4  Afghanistan         EMR  1984.0    NaN   sp

# %% [markdown]
# Often we want to select data based on certain conditions.

# %%
cond = df.year < 1981

# %%
df[cond].shape
# Out:
# (9932, 7)

# %%
df[cond & (df.country == 'Argentina') & (df.type == 'rel') & (df.sex == 'm')]
# Out:
#           country g_whoregion    year  cases type sex  age_range
# 322596  Argentina         AMR  1980.0    NaN  rel   m       14.0
# 330270  Argentina         AMR  1980.0    NaN  rel   m     1524.0
# 337944  Argentina         AMR  1980.0    NaN  rel   m     2534.0
# 345618  Argentina         AMR  1980.0    NaN  rel   m     3544.0
# 353292  Argentina         AMR  1980.0    NaN  rel   m     4554.0

# %%
gr_and_it = df.country.isin(['Greece', 'Italy'])

# %%
df[gr_and_it].tail()
# Out:
#        country g_whoregion    year  cases type sex  age_range
# 356431   Italy         EUR  2011.0    NaN  rel   m     4554.0
# 356432   Italy         EUR  2012.0    NaN  rel   m     4554.0
# 356433   Italy         EUR  2013.0  170.0  rel   m     4554.0
# 356434   Italy         EUR  2014.0    NaN  rel   m     4554.0
# 356435   Italy         EUR  2015.0  282.0  rel   m     4554.0

# %% [markdown]
# Subsets can be selected by callable functions (returning valid indexers).
# The following function performs a selection by label (along `country` and `g_whoregion`).

# %%
lambda x: ['country', 'g_whoregion']
# Out:
# <function __main__.<lambda>(x)>

# %% [markdown]
# So it can serve as a column indexer.

# %%
df.loc[:3, lambda x: ['country', 'g_whoregion']]
# Out:
#        country g_whoregion
# 0  Afghanistan         EMR
# 1  Afghanistan         EMR
# 2  Afghanistan         EMR
# 3  Afghanistan         EMR

# %% [markdown]
# The following function filters for data where the number of cases is greater than 100,000.

# %%
lambda x: x.cases > 100000
# Out:
# <function __main__.<lambda>(x)>

# %% [markdown]
# So it can serve as a row indexer.

# %%
great = df.loc[lambda x: x.cases > 100000, :]
great
# Out:
#        country g_whoregion    year     cases type sex  age_range
# 133665   India         SEA  2007.0  250051.0   sn   m     3544.0
# 187383   India         SEA  2007.0  148811.0   sn   f     3544.0
# 241101   India         SEA  2007.0  105825.0   ep   m     3544.0
# 294819   India         SEA  2007.0  101015.0   ep   f     3544.0
# 333196   India         SEA  2014.0  180319.0  rel   m     1524.0
# 333197   India         SEA  2015.0  186771.0  rel   m     1524.0
# 340870   India         SEA  2014.0  190483.0  rel   m     2534.0
# 340871   India         SEA  2015.0  197298.0  rel   m     2534.0
# 348544   India         SEA  2014.0  199850.0  rel   m     3544.0
# 348545   India         SEA  2015.0  207000.0  rel   m     3544.0
# 354519   China         WPR  2013.0  100297.0  rel   m     4554.0
# 354520   China         WPR  2014.0  102352.0  rel   m     4554.0
# 354521   China         WPR  2015.0  103685.0  rel   m     4554.0
# 356218   India         SEA  2014.0  188106.0  rel   m     4554.0
# 356219   India         SEA  2015.0  194837.0  rel   m     4554.0

# %%
df.cases.loc[lambda x: x > 100000]
# Out:
# 133665    250051.0
# 187383    148811.0
# 241101    105825.0
# 294819    101015.0
# 333196    180319.0
# 333197    186771.0
# 340870    190483.0
# 340871    197298.0
# 348544    199850.0
# 348545    207000.0
# 354519    100297.0
# 354520    102352.0
# 354521    103685.0
# 356218    188106.0
# 356219    194837.0
# Name: cases, dtype: float64

# %% [markdown]
# We may want to select or mask data while preserving the original shape.

# %%
great.where(great.country == 'India')
# Out:
#        country g_whoregion    year     cases type  sex  age_range
# 133665   India         SEA  2007.0  250051.0   sn    m     3544.0
# 187383   India         SEA  2007.0  148811.0   sn    f     3544.0
# 241101   India         SEA  2007.0  105825.0   ep    m     3544.0
# 294819   India         SEA  2007.0  101015.0   ep    f     3544.0
# 333196   India         SEA  2014.0  180319.0  rel    m     1524.0
# 333197   India         SEA  2015.0  186771.0  rel    m     1524.0
# 340870   India         SEA  2014.0  190483.0  rel    m     2534.0
# 340871   India         SEA  2015.0  197298.0  rel    m     2534.0
# 348544   India         SEA  2014.0  199850.0  rel    m     3544.0
# 348545   India         SEA  2015.0  207000.0  rel    m     3544.0
# 354519     NaN         NaN     NaN       NaN  NaN  NaN        NaN
# 354520     NaN         NaN     NaN       NaN  NaN  NaN        NaN
# 354521     NaN         NaN     NaN       NaN  NaN  NaN        NaN
# 356218   India         SEA  2014.0  188106.0  rel    m     4554.0
# 356219   India         SEA  2015.0  194837.0  rel    m     4554.0

# %%
great.mask(great.country == 'India')
# Out:
#        country g_whoregion    year     cases type  sex  age_range
# 133665     NaN         NaN     NaN       NaN  NaN  NaN        NaN
# 187383     NaN         NaN     NaN       NaN  NaN  NaN        NaN
# 241101     NaN         NaN     NaN       NaN  NaN  NaN        NaN
# 294819     NaN         NaN     NaN       NaN  NaN  NaN        NaN
# 333196     NaN         NaN     NaN       NaN  NaN  NaN        NaN
# 333197     NaN         NaN     NaN       NaN  NaN  NaN        NaN
# 340870     NaN         NaN     NaN       NaN  NaN  NaN        NaN
# 340871     NaN         NaN     NaN       NaN  NaN  NaN        NaN
# 348544     NaN         NaN     NaN       NaN  NaN  NaN        NaN
# 348545     NaN         NaN     NaN       NaN  NaN  NaN        NaN
# 354519   China         WPR  2013.0  100297.0  rel    m     4554.0
# 354520   China         WPR  2014.0  102352.0  rel    m     4554.0
# 354521   China         WPR  2015.0  103685.0  rel    m     4554.0
# 356218     NaN         NaN     NaN       NaN  NaN  NaN        NaN
# 356219     NaN         NaN     NaN       NaN  NaN  NaN        NaN

# %% [markdown]
# ### Hands-on exercises

# %% [markdown]
# 1. Select the rows of `df` where country is Greece, age is at most 24, and year is 2000. Name it `df1`.
# 2. Write the `df1` DataFrame to a CSV file located in the `data/` subdirectory. (Hint: The method is named `to_csv`.)
# 3. Read this CSV file into a DataFrame named `df2`. What do you notice about the index? (Feel free to fire up a Terminal and look at the CSV file.)

# %%
df1 = df[(df.country == 'Greece') & (df.year == 2000) & (df.age_range.isin([14, 1524]))]

# %%
df1.to_csv('/content/df1.csv')

# %%
df2 = pd.read_csv('/content/df1.csv')

# %% [markdown]
# ## Indexing

# %%
df1.index
# Out:
# Int64Index([  2768,  10442,  56486,  64160, 110204, 117878, 163922, 171596,
#             217640, 225314, 271358, 279032, 325076, 332750],
#            dtype='int64')

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=14, step=1)

# %% [markdown]
# We could specify that the first (unnamed) column should be used as the index (row labels).

# %%
pd.read_csv('/content/df1.csv', index_col=0)
# Out:
#        country g_whoregion    year  cases type sex  age_range
# 2768    Greece         EUR  2000.0    1.0   sp   m       14.0
# 10442   Greece         EUR  2000.0   10.0   sp   m     1524.0
# 56486   Greece         EUR  2000.0    0.0   sp   f       14.0
# 64160   Greece         EUR  2000.0    2.0   sp   f     1524.0
# 110204  Greece         EUR  2000.0    NaN   sn   m       14.0
# 117878  Greece         EUR  2000.0    NaN   sn   m     1524.0
# 163922  Greece         EUR  2000.0    NaN   sn   f       14.0
# 171596  Greece         EUR  2000.0    NaN   sn   f     1524.0
# 217640  Greece         EUR  2000.0    NaN   ep   m       14.0
# 225314  Greece         EUR  2000.0    NaN   ep   m     1524.0
# 271358  Greece         EUR  2000.0    NaN   ep   f       14.0
# 279032  Greece         EUR  2000.0    NaN   ep   f     1524.0
# 325076  Greece         EUR  2000.0    NaN  rel   m       14.0
# 332750  Greece         EUR  2000.0    NaN  rel   m     1524.0

# %% [markdown]
# Remember we learnt `set_index()` in the previous section? We also have `reset_index()` at our disposal.

# %%
df1.reset_index()
# Out:
#      index country g_whoregion    year  cases type sex  age_range
# 0     2768  Greece         EUR  2000.0    1.0   sp   m       14.0
# 1    10442  Greece         EUR  2000.0   10.0   sp   m     1524.0
# 2    56486  Greece         EUR  2000.0    0.0   sp   f       14.0
# 3    64160  Greece         EUR  2000.0    2.0   sp   f     1524.0
# 4   110204  Greece         EUR  2000.0    NaN   sn   m       14.0
# 5   117878  Greece         EUR  2000.0    NaN   sn   m     1524.0
# 6   163922  Greece         EUR  2000.0    NaN   sn   f       14.0
# 7   171596  Greece         EUR  2000.0    NaN   sn   f     1524.0
# 8   217640  Greece         EUR  2000.0    NaN   ep   m       14.0
# 9   225314  Greece         EUR  2000.0    NaN   ep   m     1524.0
# 10  271358  Greece         EUR  2000.0    NaN   ep   f       14.0
# 11  279032  Greece         EUR  2000.0    NaN   ep   f     1524.0
# 12  325076  Greece         EUR  2000.0    NaN  rel   m       14.0
# 13  332750  Greece         EUR  2000.0    NaN  rel   m     1524.0

# %% [markdown]
# And we are back to a default index for this DataFrame. The original index is stored in its own column.

# %%
df1.reset_index().index
# Out:
# RangeIndex(start=0, stop=14, step=1)

# %% [markdown]
# ### Hands-on exercises
#
# 4. Write the df1 DataFrame with a default index to another CSV file.
# 5. Read this other CSV file into a DataFrame, setting its index to be the original index.

# %% [markdown]
# ## Reference

# %% [markdown]
# * Current limitations with the feather format: https://github.com/wesm/feather/tree/master/python#limitations
